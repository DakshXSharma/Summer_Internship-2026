# %%
l = [10, "v", 20, 30]
print(type(l), l)
print(l[1])
# Out:
# <class 'list'> [10, 'v', 20, 30]
# v

# %%
print(l[0::2])
# Out:
# [10, 20]

# %%
print(len(l))
for i in l:
    print(i, end=" ")
# Out:
# 4
# 10 v 20 30

# %%
l = [10, 20, 30]
s = 0
for x in l:
    s += x
print(s)
# Out:
# 60

# %%
str = "Mai ek string hu"
str2 = "Sahi mein"
l = str.split()
l.append(str2)
l.append(str2.split())
print(l)
l.insert(1, "inserted")
print(l)
l.remove("hu")
print(l)
# Out:
# ['Mai', 'ek', 'string', 'hu', 'Sahi mein', ['Sahi', 'mein']]
# ['Mai', 'inserted', 'ek', 'string', 'hu', 'Sahi mein', ['Sahi', 'mein']]
# ['Mai', 'inserted', 'ek', 'string', 'Sahi mein', ['Sahi', 'mein']]

# %%
num = [1, 2, 3, 4, 5]
Sum = sum(num)
print(Sum)
Sum = sum(num, 20)
print(Sum)
# Out:
# 15
# 35

# %%
t = (10, 20, 30, 40, 20, 30, 30, {1: "java", 2: "python"})
print(t, type(t))
for i in t:
    print(i)
print(t[7][2])
# Out:
# (10, 20, 30, 40, 20, 30, 30, {1: 'java', 2: 'python'}) <class 'tuple'>
# 10
# 20
# 30
# 40
# 20
# 30
# 30
# {1: 'java', 2: 'python'}
# python

# %%
t1 = ('xyz')*7
t2 = ('xyz', 2)*7
print(t1)
print(t2)
# Out:
# xyzxyzxyzxyzxyzxyzxyz
# ('xyz', 2, 'xyz', 2, 'xyz', 2, 'xyz', 2, 'xyz', 2, 'xyz', 2, 'xyz', 2)

# %%
t3 = (34, 342, 43, 1, 999, 234, 2)
print(min(t3))
print(max(t3))
print(t3.count(34))
print(t3.index(43))
print(sum(t3))
# Out:
# 1
# 999
# 1
# 2
# 1655

# %%
s1 = {"abc", 1, "python", "network", True, "abc"}
s2 = {10, 20, 30}
print(s1, type(s1))
print(s1 | s2)
# Out:
# {1, 'python', 'network', 'abc'} <class 'set'>
# {1, 'python', 20, 'abc', 'network', 10, 30}

# %%
s3 = set()
s4 = set()

for i in range(5):
    s3.add(i)
print(s3)

for i in range(3,10,2):
    s4.add(i)
print(s4)
# Out:
# {0, 1, 2, 3, 4}
# {9, 3, 5, 7}

# %%
s3.clear()
print(s3)
# Out:
# set()
