# %%
print("asdf")
# Out:
# asdf

# %%
print("hello", 'py', sep = "_", end = " ")
print("Hi")
# Out:
# hello_py Hi

# %%
print('''Hello
      Namaste
  Hi''')
# Out:
# Hello
#       Namaste
#   Hi

# %%
a = "Namaste"
print(a)
type(a)
# Out:
# Namaste
# str

# %%
a = 10
b = 10
print(id(a))
print(id(b))
# Out:
# 140715864881880
# 140715864881880

# %%
n1 = input("Enter num 1: ")
print(n1)
# Out:
# yhb

# %%
n2 = int(input("Enter num 1: "))
print(n2)
# Out:
# 798

# %%
d = 72.08979
print(f"Number = {d:.2f}")
# Out:
# Number = 72.09

# %%
d = 72
print(f"Number = {d:.2f}")
# Out:
# Number = 72.00

# %%
x = str(2)
print(type(x))
# Out:
# <class 'str'>

# %%
string1 = 'Hello Hi'
string2 = "Namaste"
print(string1)
print(string2)
print(string2.upper())
# Out:
# Hello Hi
# Namaste
# NAMASTE

# %%
print(string1.swapcase())
print(string1.capitalize())
print(string1)
# Out:
# hELLO hI
# Hello hi
# Hello Hi

# %%
print(string1.center(101))
# Out:
#                                                Hello Hi

# %%
string3 = '  fk fgf g\tuhfgfk'
print(string3.expandtabs(tabsize = 50))
# Out:
#   fk fgf g                                        uhfgfk

# %%
print(string3.find('g'))
print(string3.index('g'))
# Out:
# 6
# 6

# %%
s = "_"
seq = ["a", "b", "c"]
print(s.join(seq))
print(seq)
type(seq)
# Out:
# a_b_c
# ['a', 'b', 'c']
# list

# %%
print(string3.ljust(40, "@"))
print(string3.lstrip())
# Out:
#   fk fgf g	uhfgfk@@@@@@@@@@@@@@@@@@@@@@@
# fk fgf g	uhfgfk

# %%
l = "qwerty"
e = "123456"
str4 = "asdwhmklh nnhlkmefg"
encode = str4.maketrans(l, e)
print(str4.translate(encode))
print(str4)
# Out:
# asd2hmklh nnhlkm3fg
# asdwhmklh nnhlkmefg

# %%
n1 = 54
n2 = 90
print(n1 is not n2)
# Out:
# True

# %%
s1 = "This is Internship"
s2 = "is"
if(s2 not in s1):
    print("Yes")
print("No")
# Out:
# No
