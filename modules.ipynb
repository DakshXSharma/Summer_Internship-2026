# %%
import greet

greet.greeting("Python")
greet.sumf(5, 4)
# Out:
# Hello Python
# 9

# %%
greet.person1['Name']
# Out:
# 'abc'

# %%
import math

print(math.acos(0.55))
print(math.acos(-0.55))
print(math.acos(0))
print(math.acos(1))
print(math.acos(-1))
# Out:
# 0.9884320889261531
# 2.15316056466364
# 1.5707963267948966
# 0.0
# 3.141592653589793

# %%
print(math.ceil(0.4))
print(math.ceil(5.3))
print(math.ceil(-5.3))
print(math.ceil(22.6))
print(math.ceil(10.0))
# Out:
# 1
# 6
# -5
# 23
# 10

# %%
n = 7
k = 5
print(math.comb(n ,k))

print(math.factorial(6))
print(math.trunc(7.798))
print(math.pi)
print(math.inf)
# Out:
# 21
# 720
# 7
# 3.141592653589793
# inf

# %%
import datetime

x = datetime.datetime.now()
print(x)
print(x.year)
# Out:
# 2026-06-02 09:51:01.673855
# 2026

# %%
import datetime

x = datetime.datetime(2026, 6, 2)
print(x)
print(x.year)
# Out:
# 2026-06-02 00:00:00
# 2026

# %%
import random

cnum = random.randrange(0, 100)
unum = int(input("Enter any number b/w 0 to 100: "))
if cnum > unum:
    print("Computer's", cnum, "is greater!")
elif cnum < unum:
    print("Computer's", cnum, "is smaller!")
else:
    print("Computer's", cnum, "is equal!!")
# Out:
# Computer's 58 is smaller!

# %%
import os

os.chdir('D:/Programming/try')
for file in os.listdir():
    print(file)
# Out:
# Travel video editing.png
# Video Editor.jpg

# %%
os.chdir('D:/Programming/try')
i = 1
for file in os.listdir():
    src = file
    dst = "image" + str(i) + ".jpg"
    os.rename(src, dst)
    i += 1
for file in os.listdir():
    print(file)
# Out:
# image1.jpg
# image2.jpg

# %%
import secrets
import string

alphabet = string.ascii_letters + string.digits
password = ''.join(secrets.choice(alphabet) for i in range(20))
print(password)
# Out:
# iet2LIbDSpKlPLmNUu9T

# %%
import qrcode

data = {
    'Name': 'Daksh Sharma',
    'url': 'https://www.github.com/DakshXSharma'
}
img = qrcode.make(data)
img.save('qr.png')

# %%
import cv2

image = cv2.imread("qr.png")
detector = cv2.QRCodeDetector()
data, vertices_array, binary_qrcode = detector.detectAndDecode(image)
if vertices_array is not None and data:
    print("QR Code Data:", data)
else:
    print("No data found!")
# Out:
# QR Code Data: {'Name': 'Daksh Sharma', 'url': 'https://www.github.com/DakshXSharma'}
