# %%
str = "Ye hai ek string"
print(str[-1])
# Out:
# g

# %%
print(str[0:10:2]) #slicing with step size 2
# Out:
# Y a k

# %%
print(str[-1::-2]) #reversing the string
print(str[0::2])
# Out:
# git eihe
# Y a ksrn

# %%
for x in str:
    print(x)
# Out:
# Y
# e
#
# h
# a
# i
#
# e
# k
#
# s
# t
# r
# i
# n
# g

# %%
str2 = "Hi, Namaste"
l = 0
for x in str2:
    l += 1
print(l)
# Out:
# 11

# %%
char1 = input("Enter a character: ")
print(char1)
print(ord(char1)) #ASCII value of the character
# Out:
# t
# 116
