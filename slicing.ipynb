# %%
import pandas as pd

df = pd.DataFrame([['a', 'b'], ['c', 'd'], ['e', 'f'], ['g', 'h']], columns = ['col1', 'col2'])
print(df, '\n')

res = df.iloc[1:3, :]
print(res)
# Out:
#   col1 col2
# 0    a    b
# 1    c    d
# 2    e    f
# 3    g    h
#
#   col1 col2
# 1    c    d
# 2    e    f

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
print(df, '\n')
df.index = ['r1', 'r2', 'r3', 'r4']
res = df.loc['r1':'r4', 'col1':'col3']
print(res)
# Out:
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 2    e    f     7     8
# 3    g    h     9     0
#
#    col1 col2  col3
# r1    a    b     3
# r2    c    d     5
# r3    e    f     7
# r4    g    h     9

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
print(df, '\n')
df.index = ['r1', 'r2', 'r3', 'r4']
res = df.iloc[0:4, 0:3]
print(res, '\n')
res = df.loc['r1':'r4', 'col1':'col3']
print(res)
# Out:
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 2    e    f     7     8
# 3    g    h     9     0
#
#    col1 col2  col3
# r1    a    b     3
# r2    c    d     5
# r3    e    f     7
# r4    g    h     9
#
#    col1 col2  col3
# r1    a    b     3
# r2    c    d     5
# r3    e    f     7
# r4    g    h     9

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
print(df, '\n')
df.index = ['r1', 'r2', 'r3', 'r4']

df.iloc[1:3, 0] = ['x', 'y']
print(df)
# Out:
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 2    e    f     7     8
# 3    g    h     9     0
#
#    col1 col2  col3  col4
# r1    a    b     3     4
# r2    x    d     5     6
# r3    y    f     7     8
# r4    g    h     9     0

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
print(df, '\n')
df.index = ['r1', 'r2', 'r3', 'r4']

df.iloc[1, 2:4] = [100, 200]
print(df)
# Out:
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 2    e    f     7     8
# 3    g    h     9     0
#
#    col1 col2  col3  col4
# r1    a    b     3     4
# r2    c    d   100   200
# r3    e    f     7     8
# r4    g    h     9     0

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
print(df, '\n')

res = df.drop(2)
print(res)
# Out:
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 2    e    f     7     8
# 3    g    h     9     0
#
#   col1 col2  col3  col4
# 0    a    b     3     4
# 1    c    d     5     6
# 3    g    h     9     0

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
df.index = ['r1', 'r2', 'r3', 'r4']
print(df, '\n')

res = df.drop('r2')
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     3     4
# r2    c    d     5     6
# r3    e    f     7     8
# r4    g    h     9     0
#
#    col1 col2  col3  col4
# r1    a    b     3     4
# r3    e    f     7     8
# r4    g    h     9     0

# %%
import pandas as pd

df = pd.DataFrame([['a', 'b', 3, 4], ['c', 'd', 5, 6], ['e', 'f', 7, 8], ['g', 'h', 9, 0]], columns = ['col1', 'col2', 'col3', 'col4'])
df.index = ['r1', 'r2', 'r3', 'r4']
print(df, '\n')

res = df[df["col4"] != 0]
print(res)
# Out:
#    col1 col2  col3  col4
# r1    a    b     3     4
# r2    c    d     5     6
# r3    e    f     7     8
# r4    g    h     9     0
#
#    col1 col2  col3  col4
# r1    a    b     3     4
# r2    c    d     5     6
# r3    e    f     7     8
