# %%
print("Name:", "Rahul,", "Age:", 18)
print("Python", "Java", "C++", sep=" | ")
print("Hello", end=" ")
print("World")
# Out:
# Name: Rahul, Age: 18
# Python | Java | C++
# Hello World

# %%
name = input("Enter your name: ")
print(f"Hello, {name}! Welcome.")
# Out:
# Hello, Daksh! Welcome.
