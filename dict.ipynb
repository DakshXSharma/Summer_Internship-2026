# %%
d = {'name': "Python", 'framework': "React", 'language': { 'name': "CPP" }}
print(d['language']['name'])
# Out:
# CPP

# %%
d2 = {}
d2['alpha1'] = "A"
print(d2)
# Out:
# {'alpha1': 'A'}

# %%
dict1 = {1: "Python", 2: "Java", 3: "CPP", 4: "Dart"}
dict2 = dict1.copy()
print(dict1)
print(dict2)
print(dict1[2])
print(dict1.get(2))
print(dict1.items())
print(dict1.keys())
dict1.update({5: "NodeJS"})
print(dict1)
print(dict2)
dict2.update(dict1)
print(dict2)
# Out:
# {1: 'Python', 2: 'Java', 3: 'CPP', 4: 'Dart'}
# {1: 'Python', 2: 'Java', 3: 'CPP', 4: 'Dart'}
# Java
# Java
# dict_items([(1, 'Python'), (2, 'Java'), (3, 'CPP'), (4, 'Dart')])
# dict_keys([1, 2, 3, 4])
# {1: 'Python', 2: 'Java', 3: 'CPP', 4: 'Dart', 5: 'NodeJS'}
# {1: 'Python', 2: 'Java', 3: 'CPP', 4: 'Dart'}
# {1: 'Python', 2: 'Java', 3: 'CPP', 4: 'Dart', 5: 'NodeJS'}
