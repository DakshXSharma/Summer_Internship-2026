# %%
n1 = 72
if (not n1):
    print("Hai")
else:
    print("Nhi hai")
print("Pakka")
# Out:
# Nhi hai
# Pakka

# %%
n2 = 90
print("n2 is not greater than n1") if (n2 < n1) else print("n2 is greater than n1")
# Out:
# n2 is greater than n1

# %%
if (n2 < n1):
    print("n2 is not greater than n1")
elif (n2 == n1):
    print("n2 is equal to n1")
else:
    print("n2 is greater than n1")
# Out:
# n2 is greater than n1

# %%
for i in range(1, 11, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10, 0, -1):
    if(i < 5):
        break
    else:
        print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
num = int(input("Enter a number: "))
for i in range(1, 11):
    print(f"{num} x {i} = {num*i}")
# Out:
# 98 x 1 = 98
# 98 x 2 = 196
# 98 x 3 = 294
# 98 x 4 = 392
# 98 x 5 = 490
# 98 x 6 = 588
# 98 x 7 = 686
# 98 x 8 = 784
# 98 x 9 = 882
# 98 x 10 = 980

# %%
for i in range(5, 0, -1):
    for j in range(5):
        print(i, j, sep = "_-_")
# Out:
# 5_-_0
# 5_-_1
# 5_-_2
# 5_-_3
# 5_-_4
# 4_-_0
# 4_-_1
# 4_-_2
# 4_-_3
# 4_-_4
# 3_-_0
# 3_-_1
# 3_-_2
# 3_-_3
# 3_-_4
# 2_-_0
# 2_-_1
# 2_-_2
# 2_-_3
# 2_-_4
# 1_-_0
# 1_-_1
# 1_-_2
# 1_-_3
# 1_-_4

# %%
s1 = "y"
while(s1 != "n"):
    s1 = input("Do you want to continue? (y/n): ")

# %%
#(✿◡‿◡)
