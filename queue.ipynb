# %%
l = []
while(True):
    print('''1. Add element to list
2. Remove element from list
3. Display first three elements of list
4. Display last three elements of list
5. Print list
6. Exit''')
    ch = int(input("Enter your choice: "))
    if ch == 1:
        ele = input("Enter element to add: ")
        l.append(ele)
    elif ch == 2:
        ele = input("Enter element to remove: ")
        if ele in l:
            l.remove(ele)
        else:
            print("Element not found in list.")
    elif ch == 3:
        print("First three elements:", l[:3])
    elif ch == 4:
        print("Last three elements:", l[-3:])
    elif ch == 5:
        print("List:", l)
    elif ch == 6:
        print("Exiting...")
        break
# Out:
# 1. Add element to list
# 2. Remove element from list
# 3. Display first three elements of list
# 4. Display last three elements of list
# 5. Print list
# 6. Exit
# 1. Add element to list
# 2. Remove element from list
# 3. Display first three elements of list
# 4. Display last three elements of list
# 5. Print list
# 6. Exit
# List: ['72']
# 1. Add element to list
# 2. Remove element from list
# 3. Display first three elements of list
# 4. Display last three elements of list
# 5. Print list
# 6. Exit
# Exiting...
